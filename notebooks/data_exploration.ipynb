# %%
import pandas as pd

df = pd.read_csv("../data/raw/BPI_Challenges_2017.csv")
df.head()
# Out:
#                   case_id                activity  \
# 0  Application_1000086665    A_Create Application
# 1  Application_1000086665             A_Submitted
# 2  Application_1000086665          W_Handle leads
# 3  Application_1000086665          W_Handle leads
# 4  Application_1000086665  W_Complete application
#
#                           timestamp
# 0  2016-08-03 15:57:21.673000+00:00
# 1  2016-08-03 15:57:21.734000+00:00
# 2  2016-08-03 15:57:21.963000+00:00
# 3  2016-08-03 15:58:28.286000+00:00
# 4  2016-08-03 15:58:28.293000+00:00

# %%
df.shape
df["activity"].nunique()
df["case_id"].nunique()
# Out:
# 31509

# %%
trace_lengths = df.groupby("case_id").size()
trace_lengths.describe()
# Out:
# count    31509.000000
# mean        38.156305
# std         16.715308
# min         10.000000
# 25%         25.000000
# 50%         35.000000
# 75%         47.000000
# max        180.000000
# dtype: float64

# %%
trace_lengths.hist(bins=50)
# Out:
# <Axes: >
