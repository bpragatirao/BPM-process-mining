# %%
import pandas as pd

X = pd.read_csv("../data/processed/sequences.csv")
y = pd.read_csv("../data/processed/labels.csv")

y["label"].value_counts().head(10)
# Out:
# label
# 24    20449
# 19    18308
# 20    16492
# 21    12008
# 13     4099
# 12     4099
# 9      3780
# 16     3772
# 0      3000
# 2      2988
# Name: count, dtype: int64

# %%
(X < 0).sum().sum()
y.isnull().sum()
# Out:
# label    0
# dtype: int64
